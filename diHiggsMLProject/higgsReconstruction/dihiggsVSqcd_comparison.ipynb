# %%
from eventReconstructionClass import eventReconstruction

# %%
testClass = eventReconstruction('pp2hh4b_CMSPhaseII_0PU', '../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root', True)
testClass.printAllOptions()
# Out:
# Transparency:  0.5
# N_Jets To Store:  4
# DeltaR Cut Between Jet and Quark:  0.4
# Higgs Mass:  125.0
# Higgs Width:  15.0
# Minimum Jet pT [GeV]:  20.0
# Maximum Jet |eta|:  2.5
# Algorithm saved for training:  equalDijetMass
# Higgs Width:  15.0

# %%
testClass.runReconstruction()
# Out:
# Setting Delphes file;  ../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root
# Finished loading branches...
# Analyzing event number 0
# Analyzing event number 2000
# Analyzing event number 4000
# Analyzing event number 6000
# Analyzing event number 8000
# Analyzing event number 10000
# Analyzing event number 12000
# Analyzing event number 14000
# Analyzing event number 16000
# Analyzing event number 18000
# Analyzing event number 20000
# Analyzing event number 22000
# Analyzing event number 24000
# Analyzing event number 26000
# Analyzing event number 28000
# Finished processing 30000 events...

# %%
testClass.eventCounterDict['closestDijetMassesToHiggs']
#testClass.outputDataForLearning
testClass.printAllAlgorithmEventTotals(['Incl'])
testClass.makeAlgorithmComparisonPlots()
# Out:
# ====================================================
# !!!! Event Counter Info For minHarmonicMeanDeltaR, Incl
# Number of Events: 30000
# Number of Events with 4 truth-matchable jets: 2663
# Number of Events Fully Matched: 1871
# Number of Events with >= 1 Pair Matched: 2006
# Efficiency For Fully Matched:  70.26 %
# Efficiency For >= 1 Pair Matched:  75.33 %
# ====================================================
# !!!! Event Counter Info For closestDijetMassesToHiggs, Incl
# Number of Events: 30000
# Number of Events with 4 truth-matchable jets: 2663
# Number of Events Fully Matched: 1834
# Number of Events with >= 1 Pair Matched: 1889
# Efficiency For Fully Matched:  68.87 %
# Efficiency For >= 1 Pair Matched:  70.94 %
# ====================================================
# !!!! Event Counter Info For equalDijetMass, Incl
# Number of Events: 30000
# Number of Events with 4 truth-matchable jets: 2663
# Number of Events Fully Matched: 1892
# Number of Events with >= 1 Pair Matched: 1940
# Efficiency For Fully Matched:  71.05 %
# Efficiency For >= 1 Pair Matched:  72.85 %
# ====================================================
# !!!! Event Counter Info For equalDeltaR, Incl
# Number of Events: 30000
# Number of Events with 4 truth-matchable jets: 2663
# Number of Events Fully Matched: 1128
# Number of Events with >= 1 Pair Matched: 1165
# Efficiency For Fully Matched:  42.36 %
# Efficiency For >= 1 Pair Matched:  43.75 %
# ====================================================
# !!!! Event Counter Info For dijetMasses, Incl
# Number of Events: 30000
# Number of Events with 4 truth-matchable jets: 2663
# Number of Events Fully Matched: 2005
# Number of Events with >= 1 Pair Matched: 2067
# Efficiency For Fully Matched:  75.29 %
# Efficiency For >= 1 Pair Matched:  77.62 %
