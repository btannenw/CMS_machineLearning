# %%
import uproot
import matplotlib.pyplot as plt
import numpy as np

t = 0.7  # transparency of plots

# %%
def fill_histograms(ht_4b, ht_hh4b, met_4b, met_hh4b, jetPt_4b, jetPt_hh4b):
    print("filling...")

    t_ht_4b = uproot.tree.TBranchMethods.array(ht_4b["ScalarHT.HT"])
    t_ht_hh4b = uproot.tree.TBranchMethods.array(ht_hh4b["ScalarHT.HT"])
    t_met_4b = uproot.tree.TBranchMethods.array(met_4b["MissingET.MET"])
    t_met_hh4b = uproot.tree.TBranchMethods.array(met_hh4b["MissingET.MET"])
    t_jetPt_4b = uproot.tree.TBranchMethods.array(jetPt_4b["Jet.PT"])
    t_jetPt_hh4b = uproot.tree.TBranchMethods.array(jetPt_hh4b["Jet.PT"])

    #plot_scalarht_new(t_ht_4b, t_ht_hh4b)
    plot_twoSamples(t_met_4b, t_met_hh4b, 'Missing ET At 0PU', 'Missing ET [GeV]', 1, 0, 200, 125)
    plot_twoSamples(t_ht_4b, t_ht_hh4b, 'Scalar HT At 0PU', 'Scalar HT [GeV]', 2, 0, 1000, 100)
    plot_twoSamples(t_jetPt_4b, t_jetPt_hh4b, 'All Jet PT At 0PU', 'Jet PT [GeV]', 3, 0, 250, 100)

# %%
def plot_twoSamples(h_4b, h_hh4b, title, xtitle, nPlot, xMin, xMax, nBins):

    h_4b = np.concatenate(h_4b).ravel().tolist()
    h_hh4b = np.concatenate(h_hh4b).ravel().tolist()

    mean_4b = np.mean(h_4b)
    stdev_4b = np.std(h_4b)
    nEntries_4b = len(h_4b)

    mean_hh4b = np.mean(h_hh4b)
    stdev_hh4b = np.std(h_hh4b)
    nEntries_hh4b = len(h_hh4b)


    s1 = "QCD 4b Production:\nentries = {}, mean = {:.4F}, std dev = {:.4F}".format(mean_4b, mean_4b, stdev_4b)
    s2 = "Dihiggs > 4b Production:\nentries = {}, mean = {:.4F}, std dev = {:.4F}".format(mean_hh4b, mean_hh4b, stdev_hh4b)
    s20 = s1 + "\n" + s2 + "\n"

    plt.figure(nPlot)
    plt.title(title)
    plt.xlabel(xtitle)
    bins = np.linspace(xMin, xMax, nBins)
    plt.hist(h_4b, bins, alpha=t, label='QCD 4b')
    plt.hist(h_hh4b, bins, alpha=t, label='hh > 4b')
    plt.legend(loc='upper right')
    #plt.text(100, 1000, s20)
    plt.show()

# %%
ht_ppTo4b_0PU = uproot.open('../../../MG5_aMC_v2_6_1/ppTo4b_14TeV/Events/run_02/tag_1_delphes_events.root')['Delphes']['ScalarHT']
ht_ppToHHto4b_0PU = uproot.open('../../../MG5_aMC_v2_6_1/ppToHHto4b_14TeV/Events/run_02_decayed_1/tag_1_delphes_events.root')['Delphes']['ScalarHT']

jet_ppTo4b_0PU = uproot.open('../../../MG5_aMC_v2_6_1/ppTo4b_14TeV/Events/run_02/tag_1_delphes_events.root')['Delphes']['Jet']
jet_ppToHHto4b_0PU = uproot.open('../../../MG5_aMC_v2_6_1/ppToHHto4b_14TeV/Events/run_02_decayed_1/tag_1_delphes_events.root')['Delphes']['Jet']

met_ppTo4b_0PU = uproot.open('../../../MG5_aMC_v2_6_1/ppTo4b_14TeV/Events/run_02/tag_1_delphes_events.root')['Delphes']['MissingET']
met_ppToHHto4b_0PU = uproot.open('../../../MG5_aMC_v2_6_1/ppToHHto4b_14TeV/Events/run_02_decayed_1/tag_1_delphes_events.root')['Delphes']['MissingET']

# %%
fill_histograms(ht_ppTo4b_0PU, ht_ppToHHto4b_0PU,
                        met_ppTo4b_0PU, met_ppToHHto4b_0PU,
                        jet_ppTo4b_0PU, jet_ppToHHto4b_0PU    )
# Out:
# filling...

# %%
delphes_4b = uproot.open('../../../MG5_aMC_v2_6_1/ppTo4b_14TeV/Events/run_02/tag_1_delphes_events.root')['Delphes']
#delphes_4b.keys()
delphes_4b["Jet"].keys()
#delphes_4b["Jet"].show()
# Out:
# [b'Jet.fUniqueID',
#  b'Jet.fBits',
#  b'Jet.PT',
#  b'Jet.Eta',
#  b'Jet.Phi',
#  b'Jet.T',
#  b'Jet.Mass',
#  b'Jet.DeltaEta',
#  b'Jet.DeltaPhi',
#  b'Jet.Flavor',
#  b'Jet.FlavorAlgo',
#  b'Jet.FlavorPhys',
#  b'Jet.BTag',
#  b'Jet.BTagAlgo',
#  b'Jet.BTagPhys',
#  b'Jet.TauTag',
#  b'Jet.Charge',
#  b'Jet.EhadOverEem',
#  b'Jet.NCharged',
#  b'Jet.NNeutrals',
#  b'Jet.Beta',
#  b'Jet.BetaStar',
#  b'Jet.MeanSqDeltaR',
#  b'Jet.PTD',
#  b'Jet.FracPt[5]',
#  b'Jet.Tau[5]',
#  b'Jet.SoftDroppedJet',
#  b'Jet.SoftDroppedSubJet1',
#  b'Jet.SoftDroppedSubJet2',
#  b'Jet.TrimmedP4[5]',
#  b'Jet.PrunedP4[5]',
#  b'Jet.SoftDroppedP4[5]',
#  b'Jet.NSubJetsTrimmed',
#  b'Jet.NSubJetsPruned',
#  b'Jet.NSubJetsSoftDropped',
#  b'Jet.Constituents',
#  b'Jet.Particles',
#  b'Jet.Area']

# %%
uproot.tree.TBranchMethods.array(delphes_4b["Jet"]["Jet.BTag"]).tolist()
len(uproot.tree.TBranchMethods.array(delphes_4b["Jet"]["Jet.BTag"]))
# Out:
# 10000

# %%
#btagsArray = uproot.tree.TBranchMethods.array(delphes_4b["Jet"]["Jet.BTag"])
btagsArray = uproot.tree.TBranchMethods.array(delphes_4b["Jet"]["Jet.BTag"]).tolist()
#btagsArray[1].count(1)

# %%
nbtagsArray = [ evt.count(1) for evt in btagsArray]
print(nbtagsArray.count(0),nbtagsArray.count(1),nbtagsArray.count(2),nbtagsArray.count(3),nbtagsArray.count(4),nbtagsArray.count(5),
      sum(nTags > 5 for nTags in nbtagsArray))
#print(nbtagsArray)
# Out:
# 1569 3709 3247 1259 200 14 2

# %%
jetPt_4b = uproot.tree.TBranchMethods.array(delphes_4b["Jet"]["Jet.PT"])
#jetPt_4b.tolist()

# %%
# Make array of nJets with raw input
jetPtList = jetPt_4b.tolist()
#print(jetPtList)
nJetsArray = [ len(evt) for evt in jetPtList]
#print(nJetsArray)

# %%
# Make array of nJets with jet pT > 30 GeV
jetPtList = jetPt_4b.tolist()
nJetsArray = [ len([1 for jetPt in evt if jetPt > 30]) for evt in jetPtList]
#print(nJetsArray)

# %%
#Make array of jets with jet pT > 30 GeV
jetPtList30[:] = [jetPet for jetPt in jetPtList[:] if jetPt > 30]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-303f6d1eac78> in <module>()
#       1 #Make array of jets with jet pT > 30 GeV
# ----> 2 jetPtList30[:] = [jetPet for jetPt in jetPtList[:] if jetPt > 30]
#
# <ipython-input-21-303f6d1eac78> in <listcomp>(.0)
#       1 #Make array of jets with jet pT > 30 GeV
# ----> 2 jetPtList30[:] = [jetPet for jetPt in jetPtList[:] if jetPt > 30]
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
type(jetPtList[0])
# Out:
# list

# %%
delphes_hh= uproot.open('../../../MG5_aMC_v2_6_1/ppToHHto4b_14TeV/Events/run_02_decayed_1/tag_1_delphes_events.root')['Delphes']
jetBranch_hh = uproot.open('../../../MG5_aMC_v2_6_1/ppToHHto4b_14TeV/Events/run_02_decayed_1/tag_1_delphes_events.root')['Delphes']["Jet"]

# %%
#jetBranch_hh.keys()
dir(uproot.tree.TBranchMethods.array(jetBranch_hh['Jet.Particles']))
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_class',
#  '_context',
#  'args',
#  'interpret',
#  'jaggedarray',
#  'tolist']

# %%
a_list = uproot.tree.TBranchMethods.array(jetBranch_hh['Jet.Particles']).tolist

# %%
len(uproot.tree.TBranchMethods.array(jetBranch_hh['Jet.PT'])[0])
# Out:
# 7

# %%
def makeSenseOfJetTruth(f_hh):
    print("working on jet truth")

    t_jetPt   = uproot.tree.TBranchMethods.array(f_hh["Jet"]["Jet.PT"])
    t_jetEta  = uproot.tree.TBranchMethods.array(f_hh["Jet"]["Jet.Eta"])
    t_jetPhi  = uproot.tree.TBranchMethods.array(f_hh["Jet"]["Jet.Phi"])
    t_jetMass = uproot.tree.TBranchMethods.array(f_hh["Jet"]["Jet.Mass"])
    t_jetParticles = uproot.tree.TBranchMethods.array(f_hh["Jet"]["Jet.Constituents"])
    
    #looping
    for iEvt in range(0,len(t_jetPt)):
        if iEvt > 4:
            continue
        
        print (t_jetPt[iEvt])
        for iJet in range(0, len(t_jetPt[iEvt])):
            print("for {0}th jet: pt={1}, eta={2}, phi={3}, mass={4}".format(iJet, round(float(t_jetPt[iEvt][iJet]), 2), round(float(t_jetEta[iEvt][iJet]), 2), round(float(t_jetPhi[iEvt][iJet]), 2), round(float(t_jetMass[iEvt][iJet]), 2)))
            for iConstituent in range(0, len(t_jetParticles.jaggedarray[iEvt])):
                #isParticle = True if 
                print("for {0}th jet, {1}th consituent type is: {2}".format(iJet, iConstituent, (t_jetParticles.jaggedarray[iEvt][iConstituent]).__class__))

# %%
t_jetParticles = uproot.tree.TBranchMethods.array(delphes_hh["Jet"]["Jet.Particles"])
#dir(uproot.tree.TBranchMethods.array(delphes_hh['Jet']['Jet.Particles']))
#len(t_jetParticles.jaggedarray)
delphes_hh["Jet"]["Jet.Constituents"].show()
ftemp= uproot.open('../../../MG5_aMC_v2_6_1/ppToHHto4b_14TeV/Events/run_02_decayed_1/tag_1_delphes_events.root')
ftemp["Delphes"].keys()
makeSenseOfJetTruth(delphes_hh)
# Out:
# Jet.Constituents           TStreamerObject            asobj(TRefArray)
# [b'Event',
#  b'Event_size',
#  b'Particle',
#  b'Particle_size',
#  b'Track',
#  b'Track_size',
#  b'Tower',
#  b'Tower_size',
#  b'EFlowTrack',
#  b'EFlowTrack_size',
#  b'EFlowPhoton',
#  b'EFlowPhoton_size',
#  b'EFlowNeutralHadron',
#  b'EFlowNeutralHadron_size',
#  b'GenJet',
#  b'GenJet_size',
#  b'GenMissingET',
#  b'GenMissingET_size',
#  b'Jet',
#  b'Jet_size',
#  b'Electron',
#  b'Electron_size',
#  b'Photon',
#  b'Photon_size',
#  b'Muon',
#  b'Muon_size',
#  b'FatJet',
#  b'FatJet_size',
#  b'MissingET',
#  b'MissingET_size',
#  b'ScalarHT',
#  b'ScalarHT_size']

# %%
def makeSenseOfParticleTruth(f_gen):
    print("working on particle truth")

    t_genD1     = uproot.tree.TBranchMethods.array(f_gen['Particle']["Particle.D1"])
    t_genD2     = uproot.tree.TBranchMethods.array(f_gen['Particle']["Particle.D2"])
    t_genPID    = uproot.tree.TBranchMethods.array(f_gen['Particle']["Particle.PID"])
    t_genStatus = uproot.tree.TBranchMethods.array(f_gen['Particle']["Particle.Status"])

    for iEvt in range(0, len(t_genD1)):
        if iEvt > 4:
            continue
            
        for iParticle in range(0, len(t_genD1[iEvt])):
            if t_genPID[iEvt][iParticle]==25:
                daughter1 = t_genD1[iEvt][iParticle]
                daughter2 = t_genD2[iEvt][iParticle]
                daughter1_PID = t_genPID[iEvt][daughter1]
                daughter2_PID = t_genPID[iEvt][daughter2]
                daughter1_Status = t_genStatus[iEvt][daughter1]
                daughter2_Status = t_genStatus[iEvt][daughter2]
                print('Event ',iEvt,'has higgs at position',iParticle,'with daughter1 (',daughter1,
                      ') of PID',daughter1_PID,'and daughter2 (',daughter2,') of PID',daughter2_PID)
                if abs(daughter1_PID) == 5 and abs(daughter2_PID)==5:
                    print('status of daughter1',daughter1_Status,'and status of daughter2',daughter2_Status)

# %%
t_genD1   = uproot.tree.TBranchMethods.array(delphes_hh['Particle']["Particle.D1"])
len(t_genD1)
makeSenseOfParticleTruth(delphes_hh)
# Out:
# working on particle truth
# Event  0 has higgs at position 3 with daughter1 ( 8 ) of PID 25 and daughter2 ( 8 ) of PID 25
# Event  0 has higgs at position 4 with daughter1 ( 9 ) of PID 25 and daughter2 ( 9 ) of PID 25
# Event  0 has higgs at position 8 with daughter1 ( 13 ) of PID 25 and daughter2 ( 13 ) of PID 25
# Event  0 has higgs at position 9 with daughter1 ( 14 ) of PID 25 and daughter2 ( 14 ) of PID 25
# Event  0 has higgs at position 13 with daughter1 ( 19 ) of PID 25 and daughter2 ( 19 ) of PID 25
# Event  0 has higgs at position 14 with daughter1 ( 20 ) of PID 25 and daughter2 ( 20 ) of PID 25
# Event  0 has higgs at position 19 with daughter1 ( 25 ) of PID 25 and daughter2 ( 25 ) of PID 25
# Event  0 has higgs at position 20 with daughter1 ( 26 ) of PID 25 and daughter2 ( 26 ) of PID 25
# Event  0 has higgs at position 25 with daughter1 ( 94 ) of PID 25 and daughter2 ( 94 ) of PID 25
# Event  0 has higgs at position 26 with daughter1 ( 95 ) of PID 25 and daughter2 ( 95 ) of PID 25
# Event  0 has higgs at position 94 with daughter1 ( 365 ) of PID 25 and daughter2 ( 365 ) of PID 25
# Event  0 has higgs at position 95 with daughter1 ( 366 ) of PID 25 and daughter2 ( 366 ) of PID 25
# Event  0 has higgs at position 365 with daughter1 ( 457 ) of PID 5 and daughter2 ( 458 ) of PID -5
# status of daughter1 23 and status of daughter2 23
# Event  0 has higgs at position 366 with daughter1 ( 510 ) of PID 5 and daughter2 ( 511 ) of PID -5
# status of daughter1 23 and status of daughter2 23
# Event  1 has higgs at position 3 with daughter1 ( 8 ) of PID 25 and daughter2 ( 8 ) of PID 25
# Event  1 has higgs at position 4 with daughter1 ( 9 ) of PID 25 and daughter2 ( 9 ) of PID 25
# Event  1 has higgs at position 8 with daughter1 ( 13 ) of PID 25 and daughter2 ( 13 ) of PID 25
# Event  1 has higgs at position 9 with daughter1 ( 14 ) of PID 25 and daughter2 ( 14 ) of PID 25
# Event  1 has higgs at position 13 with daughter1 ( 77 ) of PID 25 and daughter2 ( 77 ) of PID 25
# Event  1 has higgs at position 14 with daughter1 ( 78 ) of PID 25 and daughter2 ( 78 ) of PID 25
# Event  1 has higgs at position 77 with daughter1 ( 88 ) of PID 25 and daughter2 ( 88 ) of PID 25
# Event  1 has higgs at position 78 with daughter1 ( 89 ) of PID 25 and daughter2 ( 89 ) of PID 25
# Event  1 has higgs at position 88 with daughter1 ( 99 ) of PID 25 and daughter2 ( 99 ) of PID 25
# Event  1 has higgs at position 89 with daughter1 ( 100 ) of PID 25 and daughter2 ( 100 ) of PID 25
# Event  1 has higgs at position 99 with daughter1 ( 326 ) of PID 25 and daughter2 ( 326 ) of PID 25
# Event  1 has higgs at position 100 with daughter1 ( 327 ) of PID 25 and daughter2 ( 327 ) of PID 25
# Event  1 has higgs at position 326 with daughter1 ( 407 ) of PID 5 and daughter2 ( 408 ) of PID -5
# status of daughter1 23 and status of daughter2 23
# Event  1 has higgs at position 327 with daughter1 ( 442 ) of PID 5 and daughter2 ( 443 ) of PID -5
# status of daughter1 23 and status of daughter2 23
# Event  2 has higgs at position 3 with daughter1 ( 8 ) of PID 25 and daughter2 ( 8 ) of PID 25
# Event  2 has higgs at position 4 with daughter1 ( 9 ) of PID 25 and daughter2 ( 9 ) of PID 25
# Event  2 has higgs at position 8 with daughter1 ( 13 ) of PID 25 and daughter2 ( 13 ) of PID 25
# Event  2 has higgs at position 9 with daughter1 ( 14 ) of PID 25 and daughter2 ( 14 ) of PID 25
# Event  2 has higgs at position 13 with daughter1 ( 19 ) of PID 25 and daughter2 ( 19 ) of PID 25
# Event  2 has higgs at position 14 with daughter1 ( 20 ) of PID 25 and daughter2 ( 20 ) of PID 25
# Event  2 has higgs at position 19 with daughter1 ( 26 ) of PID 25 and daughter2 ( 26 ) of PID 25
# Event  2 has higgs at position 20 with daughter1 ( 27 ) of PID 25 and daughter2 ( 27 ) of PID 25
# Event  2 has higgs at position 26 with daughter1 ( 40 ) of PID 25 and daughter2 ( 40 ) of PID 25
# Event  2 has higgs at position 27 with daughter1 ( 41 ) of PID 25 and daughter2 ( 41 ) of PID 25
# Event  2 has higgs at position 40 with daughter1 ( 263 ) of PID 25 and daughter2 ( 263 ) of PID 25
# Event  2 has higgs at position 41 with daughter1 ( 264 ) of PID 25 and daughter2 ( 264 ) of PID 25
# Event  2 has higgs at position 263 with daughter1 ( 649 ) of PID 25 and daughter2 ( 649 ) of PID 25
# Event  2 has higgs at position 264 with daughter1 ( 650 ) of PID 25 and daughter2 ( 650 ) of PID 25
# Event  2 has higgs at position 649 with daughter1 ( 814 ) of PID 5 and daughter2 ( 815 ) of PID -5
# status of daughter1 23 and status of daughter2 23
# Event  2 has higgs at position 650 with daughter1 ( 834 ) of PID 5 and daughter2 ( 835 ) of PID -5
# status of daughter1 23 and status of daughter2 23
# Event  3 has higgs at position 3 with daughter1 ( 7 ) of PID 25 and daughter2 ( 7 ) of PID 25
# Event  3 has higgs at position 4 with daughter1 ( 8 ) of PID 25 and daughter2 ( 8 ) of PID 25
# Event  3 has higgs at position 7 with daughter1 ( 19 ) of PID 25 and daughter2 ( 19 ) of PID 25
# Event  3 has higgs at position 8 with daughter1 ( 20 ) of PID 25 and daughter2 ( 20 ) of PID 25
# Event  3 has higgs at position 19 with daughter1 ( 27 ) of PID 25 and daughter2 ( 27 ) of PID 25
# Event  3 has higgs at position 20 with daughter1 ( 28 ) of PID 25 and daughter2 ( 28 ) of PID 25
# Event  3 has higgs at position 27 with daughter1 ( 41 ) of PID 25 and daughter2 ( 41 ) of PID 25
# Event  3 has higgs at position 28 with daughter1 ( 42 ) of PID 25 and daughter2 ( 42 ) of PID 25
# Event  3 has higgs at position 41 with daughter1 ( 54 ) of PID 25 and daughter2 ( 54 ) of PID 25
# Event  3 has higgs at position 42 with daughter1 ( 55 ) of PID 25 and daughter2 ( 55 ) of PID 25
# Event  3 has higgs at position 54 with daughter1 ( 74 ) of PID 25 and daughter2 ( 74 ) of PID 25
# Event  3 has higgs at position 55 with daughter1 ( 75 ) of PID 25 and daughter2 ( 75 ) of PID 25
# Event  3 has higgs at position 74 with daughter1 ( 552 ) of PID 25 and daughter2 ( 552 ) of PID 25
# Event  3 has higgs at position 75 with daughter1 ( 553 ) of PID 25 and daughter2 ( 553 ) of PID 25
# Event  3 has higgs at position 552 with daughter1 ( 691 ) of PID 5 and daughter2 ( 692 ) of PID -5
# status of daughter1 23 and status of daughter2 23
# Event  3 has higgs at position 553 with daughter1 ( 732 ) of PID 5 and daughter2 ( 733 ) of PID -5
# status of daughter1 23 and status of daughter2 23
# Event  4 has higgs at position 3 with daughter1 ( 8 ) of PID 25 and daughter2 ( 8 ) of PID 25
# Event  4 has higgs at position 4 with daughter1 ( 9 ) of PID 25 and daughter2 ( 9 ) of PID 25
# Event  4 has higgs at position 8 with daughter1 ( 13 ) of PID 25 and daughter2 ( 13 ) of PID 25
# Event  4 has higgs at position 9 with daughter1 ( 14 ) of PID 25 and daughter2 ( 14 ) of PID 25
# Event  4 has higgs at position 13 with daughter1 ( 18 ) of PID 25 and daughter2 ( 18 ) of PID 25
# Event  4 has higgs at position 14 with daughter1 ( 19 ) of PID 25 and daughter2 ( 19 ) of PID 25
# Event  4 has higgs at position 18 with daughter1 ( 125 ) of PID 25 and daughter2 ( 125 ) of PID 25
# Event  4 has higgs at position 19 with daughter1 ( 126 ) of PID 25 and daughter2 ( 126 ) of PID 25
# Event  4 has higgs at position 125 with daughter1 ( 164 ) of PID 25 and daughter2 ( 164 ) of PID 25
# Event  4 has higgs at position 126 with daughter1 ( 165 ) of PID 25 and daughter2 ( 165 ) of PID 25
# Event  4 has higgs at position 164 with daughter1 ( 195 ) of PID 25 and daughter2 ( 195 ) of PID 25
# Event  4 has higgs at position 165 with daughter1 ( 196 ) of PID 25 and daughter2 ( 196 ) of PID 25
# Event  4 has higgs at position 195 with daughter1 ( 685 ) of PID 25 and daughter2 ( 685 ) of PID 25
# Event  4 has higgs at position 196 with daughter1 ( 686 ) of PID 25 and daughter2 ( 686 ) of PID 25
# Event  4 has higgs at position 685 with daughter1 ( 858 ) of PID 5 and daughter2 ( 859 ) of PID -5
# status of daughter1 23 and status of daughter2 23
# Event  4 has higgs at position 686 with daughter1 ( 881 ) of PID 5 and daughter2 ( 882 ) of PID -5
# status of daughter1 23 and status of daughter2 23

# %%
def returnListOfTruthBQuarkIndicesByDaughters(a_D1, a_D2, a_PID):
    bQuarkIndices = []
    
    for iParticle in range(0, len(a_D1)):
        if a_PID[iParticle]==25:
            daughter1 = a_D1[iParticle]
            daughter2 = a_D2[iParticle]
            daughter1_PID = a_PID[daughter1]
            daughter2_PID = a_PID[daughter2]
            #print('Event ',iEvt,'has higgs at position',iParticle,'with daughter1 (',daughter1,
            #    ') of PID',daughter1_PID,'and daughter2 (',daughter2,') of PID',daughter2_PID)
            if abs(daughter1_PID) == 5 and abs(daughter2_PID)==5:
                bQuarkIndices.append(daughter1)
                bQuarkIndices.append(daughter2)
    
    return bQuarkIndices


def returnListOfTruthBQuarkIndicesByStatus(a_status):
    bQuarkIndices = []

    for iParticle in range(0, len(a_status)):
        if a_status[iParticle]==23:
            bQuarkIndices.append(iParticle)

    return bQuarkIndices
    
    
    
delphes_hh= uproot.open('../../../MG5_aMC_v2_6_1/ppToHHto4b_14TeV/Events/run_02_decayed_1/tag_1_delphes_events.root')['Delphes']
#b_particles = uproot.tree.TBranchMethods.array(delphes_hh['Particle'])
l_genD1     = uproot.tree.TBranchMethods.array(delphes_hh["Particle.D1"]).tolist()
l_genD2     = uproot.tree.TBranchMethods.array(delphes_hh['Particle']["Particle.D2"]).tolist()
l_genPID    = uproot.tree.TBranchMethods.array(delphes_hh['Particle']["Particle.PID"]).tolist()
l_genStatus = uproot.tree.TBranchMethods.array(delphes_hh['Particle']["Particle.Status"]).tolist()
    
#dir(b_particles)
for iEvt in range(0,delphes_hh.fEntries):
    if iEvt > 4:
        continue
    indicesByDaughters = returnListOfTruthBQuarkIndicesByDaughters(l_genD1[iEvt], l_genD2[iEvt], l_genPID[iEvt])
    indicesByStatus    = returnListOfTruthBQuarkIndicesByStatus(l_genStatus[iEvt])
    
    print(indicesByDaughters, indicesByStatus)
# Out:
# [457, 458, 510, 511] [457, 458, 510, 511]
# [407, 408, 442, 443] [407, 408, 442, 443]
# [814, 815, 834, 835] [814, 815, 834, 835]
# [691, 692, 732, 733] [691, 692, 732, 733]
# [858, 859, 881, 882] [858, 859, 881, 882]
